# %%
import pandas as pd

# %%
df = pd.read_csv("test2.csv")

# %%
df.head()
# Out:
#    height  weight  gender  age   name  \
# 0     180      73    Male   27  NRISF
# 1     152      73  Female   49  MWMBO
# 2     181      86  Female   57  MHJLU
# 3     176      70    Male   47  EQSEM
# 4     176      66  Female   63  RGMRY
#
#                                          description  \
# 0  sample_text0 sample_text1 sample_text2 sample_...
# 1  sample_text0 sample_text1 sample_text2 sample_...
# 2  sample_text0 sample_text1 sample_text2 sample_...
# 3             sample_text0 sample_text1 sample_text2
# 4             sample_text0 sample_text1 sample_text2
#
#                                        description_2 multi_choice_1  \
# 0             sample_text0 sample_text1 sample_text2        choiceB
# 1  sample_text0 sample_text1 sample_text2 sample_...        choiceA
# 2             sample_text0 sample_text1 sample_text2        choiceB
# 3             sample_text0 sample_text1 sample_text2        choiceB
# 4  sample_text0 sample_text1 sample_text2 sample_...        choiceA
#
#   multi_choice_2  num1  num2  num3
# 0       choice_F   951   506   492
# 1       choice_F   717   239   306
# 2       choice_F   157   816   349
# 3       choice_F   817   190   535
# 4       choice_C   179   130   774

# %%
df['ref_answer'] = "Paris"

# %%
df
# Out:
#      height  weight  gender  age   name  \
# 0       180      73    Male   27  NRISF
# 1       152      73  Female   49  MWMBO
# 2       181      86  Female   57  MHJLU
# 3       176      70    Male   47  EQSEM
# 4       176      66  Female   63  RGMRY
# ..      ...     ...     ...  ...    ...
# 995     162      55    Male   44  PGHYP
# 996     152      69  Female   44  WPDSI
# 997     166      62  Female   53  VVMIE
# 998     172      67    Male   42  NSKKD
# 999     159      84    Male   33  EWTRF
#
#                                            description  \
# 0    sample_text0 sample_text1 sample_text2 sample_...
# 1    sample_text0 sample_text1 sample_text2 sample_...
# 2    sample_text0 sample_text1 sample_text2 sample_...
# 3               sample_text0 sample_text1 sample_text2
# 4               sample_text0 sample_text1 sample_text2
# ..                                                 ...
# 995  sample_text0 sample_text1 sample_text2 sample_...
# 996             sample_text0 sample_text1 sample_text2
# 997             sample_text0 sample_text1 sample_text2
# 998             sample_text0 sample_text1 sample_text2
# 999  sample_text0 sample_text1 sample_text2 sample_...
#
#                                          description_2 multi_choice_1  \
# 0               sample_text0 sample_text1 sample_text2        choiceB
# 1    sample_text0 sample_text1 sample_text2 sample_...        choiceA
# 2               sample_text0 sample_text1 sample_text2        choiceB
# 3               sample_text0 sample_text1 sample_text2        choiceB
# 4    sample_text0 sample_text1 sample_text2 sample_...        choiceA
# ..                                                 ...            ...
# 995  sample_text0 sample_text1 sample_text2 sample_...        choiceA
# 996  sample_text0 sample_text1 sample_text2 sample_...        choiceB
# 997  sample_text0 sample_text1 sample_text2 sample_...        choiceA
# 998  sample_text0 sample_text1 sample_text2 sample_...        choiceC
# 999  sample_text0 sample_text1 sample_text2 sample_...        choiceA
#
#     multi_choice_2  num1  num2  num3 ref_answer
# 0         choice_F   951   506   492      Paris
# 1         choice_F   717   239   306      Paris
# 2         choice_F   157   816   349      Paris
# 3         choice_F   817   190   535      Paris
# 4         choice_C   179   130   774      Paris
# ..             ...   ...   ...   ...        ...
# 995       choice_F   930   469   389      Paris
# 996       choice_C   517   796   430      Paris
# 997       choice_C   555   857   540      Paris
# 998       choice_D   170   445   442      Paris
# 999       choice_F   883   939    45      Paris
#
# [1000 rows x 13 columns]

# %%
df.to_csv("test2.csv",index=False)

# %%
import pandas as pd

df = pd.read_csv("test3.csv")
df = df.head(100)
df.to_csv("test_100.csv",index=False)
